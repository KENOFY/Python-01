# %% [markdown]
# <a href="https://colab.research.google.com/github/KENOFY/Python-01/blob/main/201_T03_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from datetime import datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive/', force_remount=True)
# Out:
# Mounted at /content/drive/

# %%
root_path = 'gdrive/MyDrive/Data/200'

# %%
stock = pd.read_csv("/content/drive/MyDrive/Data/200/201-T03-01.csv",index_col='Date', parse_dates=['Date'])

# %%
stock.head(n=8)
# Out:
#              Open   High    Low  Close   Volume Name
# Date
# 2006-01-03  77.76  79.35  77.24  79.11  3117200  MMM
# 2006-01-04  79.49  79.49  78.25  78.71  2558000  MMM
# 2006-01-05  78.41  78.65  77.56  77.99  2529500  MMM
# 2006-01-06  78.64  78.90  77.64  78.63  2479500  MMM
# 2006-01-09  78.50  79.83  78.46  79.02  1845600  MMM
# 2006-01-10  79.00  79.01  78.08  78.53  1919900  MMM
# 2006-01-11  78.44  78.66  77.84  78.37  1911900  MMM
# 2006-01-12  78.20  78.23  77.20  77.70  2121100  MMM

# %%
#g_stk = stock.query('Name == "GOOGL"')
g_stk = stock.loc[stock['Name'] == "GOOGL"]

# %%
g_stk.head()
# Out:
#               Open    High     Low   Close    Volume   Name
# Date
# 2006-01-03  211.47  218.05  209.32  217.83  13137450  GOOGL
# 2006-01-04  222.17  224.70  220.09  222.84  15292353  GOOGL
# 2006-01-05  223.22  226.00  220.97  225.85  10815661  GOOGL
# 2006-01-06  228.66  235.49  226.85  233.06  17759521  GOOGL
# 2006-01-09  233.44  236.94  230.70  233.68  12795837  GOOGL

# %%
#g_stk['Ticks'] = range(0,len(g_stk.index.values))
#g_stk.insert(loc = -1, column = 'Ticks', value = (range(0,len(g_stk.index.values))))
g_stk.head()
# Out:
#               Open    High     Low   Close    Volume   Name  Ticks
# Date
# 2006-01-03  211.47  218.05  209.32  217.83  13137450  GOOGL      0
# 2006-01-04  222.17  224.70  220.09  222.84  15292353  GOOGL      1
# 2006-01-05  223.22  226.00  220.97  225.85  10815661  GOOGL      2
# 2006-01-06  228.66  235.49  226.85  233.06  17759521  GOOGL      3
# 2006-01-09  233.44  236.94  230.70  233.68  12795837  GOOGL      4

# %%
fig = plt.figure(1)
ax1 = fig.add_subplot(111)
ax1.set_xlabel('Ticks')
ax1.set_ylabel('Price')
ax1.set_title('Original Plot')
ax1.plot('Ticks', 'Open', data = g_stk);

# %%
g_stk['Rolling_Mean80'] = g_stk['Open'].rolling(80).mean()
g_stk['Rolling_Mean'] = g_stk['Open'].rolling(10).mean()
g_stk.head(99)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#               Open    High     Low  ...  Ticks  Rolling_Mean Rolling_Mean80
# Date                                ...
# 2006-01-03  211.47  218.05  209.32  ...      0           NaN            NaN
# ...

# %%
g_stk.iloc[1:10]
# Out:
#               Open    High     Low  ...  Ticks  Rolling_Mean Rolling_Mean80
# Date                                ...
# 2006-01-04  222.17  224.70  220.09  ...      1           NaN            NaN
# 2006-01-05  223.22  226.00  220.97  ...      2           NaN            NaN
# 2006-01-06  228.66  235.49  226.85  ...      3           NaN            NaN
# 2006-01-09  233.44  236.94  230.70  ...      4           NaN            NaN
# 2006-01-10  232.44  235.36  231.25  ...      5           NaN            NaN
# 2006-01-11  235.87  237.79  234.82  ...      6           NaN            NaN
# 2006-01-12  237.10  237.73  230.98  ...      7           NaN            NaN
# 2006-01-13  232.39  233.68  231.04  ...      8           NaN            NaN
# 2006-01-17  231.76  235.18  231.50  ...      9       228.852            NaN
#
# [9 rows x 9 columns]

# %%
filt_g = g_stk[(g_stk['Ticks'] >= 800) & (g_stk['Ticks'] <= 1100)]
filt_g.head()
# Out:
#               Open    High     Low   Close   Volume   Name  Ticks  Rolling_Mean
# Date
# 2009-03-10  149.27  155.41  147.27  154.24  6731733  GOOGL    800    157.606125
# 2009-03-11  155.21  160.16  153.01  159.11  5926878  GOOGL    801    157.656500
# 2009-03-12  158.93  162.66  156.98  161.93  5026330  GOOGL    802    157.817750
# 2009-03-13  163.21  163.89  159.67  162.37  3907609  GOOGL    803    157.960625
# 2009-03-16  163.16  165.03  159.45  160.00  4947256  GOOGL    804    158.104500

# %%
fig, axes = plt.subplots(nrows = 1, ncols = 2, figsize = (15,5));
axes[0].plot('Ticks', 'Open', data = g_stk);
axes[0].set_title('Original');
axes[1].plot('Ticks', 'Rolling_Mean', data = g_stk);
axes[1].set_title('Smoothed (Rolling_Mean)');
